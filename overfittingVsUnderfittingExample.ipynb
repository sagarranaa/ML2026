# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarranaa/ML2026/blob/main/overfittingVsUnderfittingExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
#create dataset
X=np.array([1,2,3,4,5,6,7]).reshape(-1,1)
y=([2,3,45,6,7,8,9])

# %%
# Linear Model
model=LinearRegression()
model.fit(X,y)
pred = model.predict(X)

# %%
# Plot it
plt.scatter(X,y)
plt.plot(X,pred,color='red')
plt.show()

# %%
# overfitting Example
# now create a complex model
poly_model = make_pipeline(
    PolynomialFeatures(degree=6),
    LinearRegression()
)

poly_model.fit(X,y)

pred2 = poly_model.predict(X)

# %%
# Plot overfitting example
plt.scatter(X,y)
plt.plot(X,pred2,color='green')
plt.show()

# %%
#### why overfitting happens
# Too complex model
# Too many features
# small dataset
# noise in data
